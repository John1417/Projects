# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./samples/blood-component-values.csv")

# %%
df.head()
# Out:
#    Serial No. Blood Group  LBXWBCSI  LBXLYPCT  LBXMOPCT  LBXNEPCT  LBXEOPCT  \
# 0        1001          B+       5.1      27.0       6.7      60.1       5.1
# 1        1002          B-      17.6      55.5       2.8      36.9       4.6
# 2        1003          A-       5.1      44.9      10.4      36.1       7.6
# 3        1004         AB+       5.6      27.2       9.8      58.7       3.2
# 4        1005         AB+       7.5      34.8       8.2      54.3       1.5
#
#    LBXBAPCT  LBDLYMNO  LBDMONO  ...  LBDBANO  LBXRBCSI  LBXHGB  LBXHCT  \
# 0       1.1       1.4      0.3  ...      0.1      5.29    16.4    45.9
# 1       0.2       9.8      0.5  ...      0.0      4.97    14.1    40.2
# 2       1.0       2.3      0.5  ...      0.1      4.65    13.7    42.2
# 3       1.2       1.5      0.5  ...      0.1      4.21    12.8    38.9
# 4       1.1       2.6      0.6  ...      0.1      4.80    12.9    38.2
#
#    LBXMCVSI  LBXMCHSI  LBXMC  LBXRDW  LBXPLTSI  LBXMPSI
# ...

# %%
df.shape
# Out:
# (7944, 22)

# %%
df.describe()
# Out:
#         Serial No.     LBXWBCSI     LBXLYPCT     LBXMOPCT     LBXNEPCT  \
# count  7944.000000  7944.000000  7944.000000  7944.000000  7944.000000
# mean   4972.500000     6.994700    33.832880     7.701221    54.663394
# std    2293.379602     2.245716    10.771788     2.552985    11.960306
# min    1001.000000     1.700000     2.700000     0.600000     0.800000
# 25%    2986.750000     5.500000    26.300000     6.100000    47.200000
# 50%    4972.500000     6.600000    32.600000     7.500000    55.600000
# 75%    6958.250000     8.100000    40.300000     8.900000    63.200000
# max    8944.000000    54.700000    83.200000    66.900000    96.600000
#
#           LBXEOPCT     LBXBAPCT     LBDLYMNO      LBDMONO      LBDNENO  ...  \
# count  7944.000000  7944.000000  7944.000000  7944.000000  7944.000000  ...
# mean      3.118341     0.725793     2.314904     0.523401     3.895859  ...
# std       2.492585     0.720421     1.149226     0.232335     1.700490  ...
# ...

# %%
df.isna().sum()
# Out:
# Serial No.     0
# Blood Group    0
# LBXWBCSI       0
# LBXLYPCT       0
# LBXMOPCT       0
# LBXNEPCT       0
# LBXEOPCT       0
# LBXBAPCT       0
# LBDLYMNO       0
# LBDMONO        0
# LBDNENO        0
# LBDEONO        0
# LBDBANO        0
# LBXRBCSI       0
# LBXHGB         0
# LBXHCT         0
# LBXMCVSI       0
# LBXMCHSI       0
# LBXMC          0
# LBXRDW         0
# LBXPLTSI       0
# LBXMPSI        0
# dtype: int64

# %%
df['LBXWBCSI'].plot(kind="violin", title="WBC Count Histogram")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29060\3534904455.py in <module>
# ----> 1 df['LBXWBCSI'].plot(kind="violin", title="WBC Count Histogram")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     903
#     904         if kind not in self._all_kinds:
# --> 905             raise ValueError(f"{kind} is not a valid plot kind")
#     906
#     907         # The original data structured can be transformed before passed to the
#
# ValueError: violin is not a valid plot kind

# %%
df['LBXWBCSI'].plot(kind="violin", title="WBC Count Histogram")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29060\3534904455.py in <module>
# ----> 1 df['LBXWBCSI'].plot(kind="violin", title="WBC Count Histogram")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     903
#     904         if kind not in self._all_kinds:
# --> 905             raise ValueError(f"{kind} is not a valid plot kind")
#     906
#     907         # The original data structured can be transformed before passed to the
#
# ValueError: violin is not a valid plot kind

# %%
df['RBCSI'].plot(kind="violin", title="RBC Count Histogram")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RBCSI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[['LBXRBCSI']].plot(kind="box", title="RBC box plots")
# Out:
# <AxesSubplot:title={'center':'RBC box plots'}>

# %%
df[['LBXRBCSI']].plot(kind="hist", title="RBC Box Plot")
# Out:
# <AxesSubplot:title={'center':'RBC Box Plot'}, ylabel='Frequency'>

# %%
df[['HGB','WBCSI']].plot(x="HGB",y="WBCSI",kind="scatter", title="Relationship between HGB and WBC")
# Out:
# <AxesSubplot:title={'center':'Relationship between HGB and WBC'}, xlabel='HGB', ylabel='WBCSI'>

# %%
df[['HGB','RBCSI']].plot(x="HGB",y="RBCSI",kind="scatter", title="Relationship between Hemoglobin and Red Blood Cells")
# Out:
# <AxesSubplot:title={'center':'Relationship between Hemoglobin and Red Blood Cells'}, xlabel='HGB', ylabel='RBCSI'>

# %%
df[['PLTSI','WBCSI']].plot(x="PLTSI",y="WBCSI",kind="scatter", title="Relationship between Platlets and Hemoglobin")
# Out:
# <AxesSubplot:title={'center':'Relationship between Platlets and Hemoglobin'}, xlabel='PLTSI', ylabel='WBCSI'>

# %%
import seaborn as sns

corr = df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
