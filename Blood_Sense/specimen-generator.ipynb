# %%
import pickle as pkl
import pandas as pd

# %%
with open("test.pkl",'rb') as p:
    content = pkl.load(p)

# %%
df = pd.DataFrame(content)

# %%
df
# Out:
#                                                     0  \
# 0   {'WBC': 7.01, 'RBC': 4.61, 'HGB': 150.96, 'HCT...
# 1   {'WBC': 8.28, 'RBC': 5.3, 'HGB': 170.03, 'HCT'...
# 2   {'WBC': 5.54, 'RBC': 5.35, 'HGB': 159.5, 'HCT'...
# 3   {'WBC': 9.67, 'RBC': 5.13, 'HGB': 145.4, 'HCT'...
# 4   {'WBC': 4.99, 'RBC': 5.28, 'HGB': 177.13, 'HCT...
# ..                                                ...
# 95  {'WBC': 6.61, 'RBC': 4.32, 'HGB': 134.98, 'HCT...
# 96  {'WBC': 8.97, 'RBC': 3.95, 'HGB': 132.48, 'HCT...
# 97  {'WBC': 7.62, 'RBC': 5.53, 'HGB': 160.97, 'HCT...
# 98  {'WBC': 6.14, 'RBC': 5.48, 'HGB': 137.47, 'HCT...
# 99  {'WBC': 8.77, 'RBC': 4.33, 'HGB': 137.99, 'HCT...
#
#                                                     1  \
# 0   {'WBC': 6.53, 'RBC': 4.92, 'HGB': 140.04, 'HCT...
# 1   {'WBC': 5.74, 'RBC': 4.39, 'HGB': 124.46, 'HCT...
# 2   {'WBC': 8.26, 'RBC': 5.04, 'HGB': 147.07, 'HCT...
# 3   {'WBC': 7.32, 'RBC': 4.71, 'HGB': 142.43, 'HCT...
# ...

# %%
df['RBC'].plot(kind="hist")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6576\1337220469.py in <module>
# ----> 1 df['RBC'].plot(kind="hist")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
# --> 389             raise KeyError(key)
#     390         return super().get_loc(key, method=method, tolerance=tolerance)
#     391
#
# KeyError: 'RBC'

# %%
df = pd.read_excel("samples/CBC_G_SAMPLE.xlsx")

# %%
df
# Out:
#        WBC  LYPCT  MOPCT  NEPCT  EOPCT  BAPCT  LYMNO  MONO  NENO  EONO  BANO  \
# 0      5.1   27.0    6.7   60.1    5.1    1.1    1.4   0.3   3.1   0.3   0.1
# 1     17.6   55.5    2.8   36.9    4.6    0.2    9.8   0.5   6.5   0.8   0.0
# 2      5.1   44.9   10.4   36.1    7.6    1.0    2.3   0.5   1.8   0.4   0.1
# 3      5.6   27.2    9.8   58.7    3.2    1.2    1.5   0.5   3.3   0.2   0.1
# 4      7.5   34.8    8.2   54.3    1.5    1.1    2.6   0.6   4.1   0.1   0.1
# ...    ...    ...    ...    ...    ...    ...    ...   ...   ...   ...   ...
# 8950   6.6   27.4    5.3   65.8    1.3    0.3    1.8   0.3   4.3   0.1   0.0
# 8951  10.9   23.7    7.1   67.7    1.6    0.0    2.6   0.8   7.4   0.2   0.0
# 8952   5.1   37.8    6.4   53.5    1.4    0.9    1.9   0.3   2.7   0.1   0.0
# 8953   4.6   40.2    9.1   47.6    2.8    0.4    1.8   0.4   2.2   0.1   0.0
# 8954   8.9   19.2    5.1   72.6    2.5    0.7    1.7   0.5   6.5   0.2   0.1
#
# ...

# %%
df = df.dropna(axis=0,how="all")

# %%
df.to_excel("CBC_G_SAMPLES_FORMATTED.xlsx")
